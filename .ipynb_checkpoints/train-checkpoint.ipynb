# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import seaborn as sns 
from sklearn.preprocessing import OneHotEncoder

# %%
train_path = 'train.csv'
test_path  = 'test.csv'
train_ds = pd.read_csv(train_path)
test_ds  = pd.read_csv(test_path)

# %%
train_ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_ds.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
check  = pd.DataFrame(train_ds.isnull().sum())
check
# Out:
#                  0
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# ...            ...
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
#
# [81 rows x 1 columns]

# %%
def categorical_numeric_features(train_ds):

    categorical_features = []
    numeric_features = []
    
    for column_name in train_ds.columns:
        if train_ds[column_name].dtype == 'object':
            categorical_features.append(column_name)
        else:
            numeric_features.append(column_name)
    return categorical_features , numeric_features

# %%
train_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
categorical_features , numeric_features = categorical_numeric_features(train_ds)

numeric_data = train_ds[numeric_features]
corr_mat = numeric_data.corr()
plt.figure(figsize=(16,10) ,dpi =500)
sns.heatmap(corr_mat,annot=True,fmt=".1f", linewidth=.5)
plt.show()

# %%
train_ds =train_ds.drop(  ['MSSubClass' , 'OverallCond' , 'KitchenAbvGr' , 'EnclosedPorch'  ,
                           'Id' , 'BsmtFinSF2' , 'LowQualFinSF' , 'BsmtHalfBath' , '3SsnPorch' ,
                           'ScreenPorch' ,'PoolArea' , 'MiscVal' ,'MoSold' ,'YrSold', 'Street' ,'Alley' ,
                           'Utilities' ,'LotFrontage' , 'MasVnrType' , 'FireplaceQu', 'PoolQC' ,  'Fence', 'MiscFeature' ]  ,axis = 1)

# %%
categorical_features , numeric_features = categorical_numeric_features(train_ds)

numeric_data = train_ds[numeric_features]

corr_mat = numeric_data.corr()
# plt.figure(figsize=(16,10) ,dpi =500)
# sns.heatmap(corr_mat,annot=True,fmt=".1f", linewidth=.5)
# plt.show()
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(corr_mat,cmap='viridis',fmt=".1f" , annot=True ,linewidth=.5)
# Out:
# <Axes: >

# %%
train_ds[categorical_features ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   LotShape       1460 non-null   object
#  2   LandContour    1460 non-null   object
#  3   LotConfig      1460 non-null   object
#  4   LandSlope      1460 non-null   object
#  5   Neighborhood   1460 non-null   object
#  6   Condition1     1460 non-null   object
#  7   Condition2     1460 non-null   object
#  8   BldgType       1460 non-null   object
#  9   HouseStyle     1460 non-null   object
#  10  RoofStyle      1460 non-null   object
#  11  RoofMatl       1460 non-null   object
#  12  Exterior1st    1460 non-null   object
#  13  Exterior2nd    1460 non-null   object
#  14  ExterQual      1460 non-null   object
#  15  ExterCond      1460 non-null   object
#  16  Foundation     1460 non-null   object
# ...

# %%
train_ds = train_ds.drop(['Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 
                       'RoofMatl', 'LandContour', 'LotConfig', 'LandSlope', 'ExterQual', 
                       'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                       'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 
                       'Electrical', 'Functional', 'PavedDrive'] , axis =1)

# %%
train_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   LotArea        1460 non-null   int64
#  2   LotShape       1460 non-null   object
#  3   Neighborhood   1460 non-null   object
#  4   OverallQual    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   Exterior1st    1460 non-null   object
#  8   Exterior2nd    1460 non-null   object
#  9   MasVnrArea     1452 non-null   float64
#  10  BsmtFinSF1     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  FullBath       1460 non-null   int64
# ...

# %%
def encode_categorical_features(train_ds, categorical_features):

  encoder = OneHotEncoder(sparse_output=False, drop='first')
  encoded_data = encoder.fit_transform(train_ds[categorical_features])
  encoded_feature_names = encoder.get_feature_names_out(categorical_features)
  encoded_df = pd.DataFrame(encoded_data, columns=encoded_feature_names)
  df_encoded = pd.concat([train_ds.drop(columns=categorical_features), encoded_df], axis=1)

  return df_encoded

# %%
categorical_features , numeric_features = categorical_numeric_features(train_ds)
df_encoded = encode_categorical_features(train_ds ,categorical_features )

# %%
test_ds = test_ds.drop(['Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 
                       'RoofMatl', 'LandContour', 'LotConfig', 'LandSlope', 'ExterQual', 
                       'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                       'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 
                       'Electrical', 'Functional', 'PavedDrive' , 'MSSubClass' , 'OverallCond' , 'KitchenAbvGr' , 'EnclosedPorch'  ,
                           'Id' , 'BsmtFinSF2' , 'LowQualFinSF' , 'BsmtHalfBath' , '3SsnPorch' ,
                           'ScreenPorch' ,'PoolArea' , 'MiscVal' ,'MoSold' ,'YrSold', 'Street' ,'Alley' ,
                           'Utilities' ,'LotFrontage' , 'MasVnrType' , 'FireplaceQu', 'PoolQC' ,  'Fence', 'MiscFeature'] , axis =1)

test_categorical_features , test_numeric_features = categorical_numeric_features(test_ds)
encoded_test = encode_categorical_features(test_ds , test_categorical_features)

# %%
encoded_test = encoded_test.dropna(axis = 0 )

# %%
df_encoded = df_encoded.dropna(axis =0)

# %%
X = df_encoded.drop(['SalePrice'] , axis =1)
Y = df_encoded['SalePrice']

x_train ,  x_test , y_train , y_test = train_test_split( X, Y , test_size = 0.2)

# %%
x_train.shape
# Out:
# (1096, 117)

# %%
y_train.shape
# Out:
# (1096,)

# %%
plt.scatter(df_encoded ,df_encoded )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(encoded_test ,encoded_test )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error

# %%
def results_models(x_train, y_train, x_test, y_test):
    
    
    results = []
    
    # Linear Regression
    model = LinearRegression()
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'linearregression',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # Linear Regression with Polynomial Features
    poly_transformer = PolynomialFeatures(degree=2)
    X_train_poly = poly_transformer.fit_transform(x_train)
    X_test_poly = poly_transformer.transform(x_test)
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    predictions = model.predict(X_test_poly)
    results.append({
          'model': 'linearregression_poly_f',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # Decision Tree Regressor
    model = DecisionTreeRegressor()
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'DecisionTreeRegressor',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # Random Forest Regressor
    model = RandomForestRegressor(n_estimators=100)
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'RandomForestRegressor',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # SVR
    model = SVR(kernel='rbf', C=1.0)
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'SVR',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # KNeighborsRegressor
    model = KNeighborsRegressor(n_neighbors=21)
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'KNeighborsRegressor',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    
    # Gradient Boosting Regressor
    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1)
    model.fit(x_train , y_train)
    predictions = model.predict(x_test)
    results.append({
          'model': 'GradientBoostingRegressor',
          'mse': mean_squared_error(y_test, predictions),
          'mae': mean_absolute_error(y_test, predictions),
          'r2': r2_score(y_test, predictions)
      })
    return results

# %%
reults = results_models(x_train, y_train, x_test, y_test)
pd.DataFrame(reults)
# Out:
#                        model           mse            mae         r2
# 0           linearregression  1.338943e+09   22087.816043   0.835455
# 1    linearregression_poly_f  6.089420e+11  284936.650055 -73.833707
# 2      DecisionTreeRegressor  1.488783e+09   24873.000000   0.817041
# 3      RandomForestRegressor  1.102475e+09   19786.360883   0.864515
# 4                        SVR  8.528136e+09   61145.353559  -0.048034
# 5        KNeighborsRegressor  4.071936e+09   34767.904069   0.499594
# 6  GradientBoostingRegressor  1.013513e+09   19326.321778   0.875448

# %%
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1)
model.fit(x_train , y_train)
predictions = model.predict(x_test)

# %%
id = [i for i in range ( 0, 275)]
submission = pd.DataFrame({'Id': id  , 'SalePrice':predictions[:1459]})
submission.to_csv('submission_2.csv', index=False)
submission.tail(3)
# print (len(predictions[:1459]))
# Out:
#       Id      SalePrice
# 272  272  340353.844422
# 273  273  145086.146402
# 274  274  319410.649822

# %%
submission.shape
